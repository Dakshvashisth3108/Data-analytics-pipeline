# %% [markdown]
# # Gold KPI exploration
# Read gold marts with pandas for ad-hoc analysis.

# %%
import sys, pathlib, pandas as pd
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from utils import gold_path

head = pd.read_parquet(gold_path('gold_headcount'))
head.head()
