# %% [markdown]
# # Bronze layer exploration
# Quick look at raw Parquet for any HCM stream.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))

from utils import build_spark, bronze_path
spark = build_spark('explore-bronze')

# %%
df = spark.read.parquet(bronze_path('employees'))
df.printSchema()
df.show(5, truncate=False)
print('rows:', df.count())
